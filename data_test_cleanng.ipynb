# %% [markdown]
# <a href="https://colab.research.google.com/github/Samreeneducation/thesis/blob/master/data_test_cleanng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ab4bce73-eb93-4f75-a249-24929f3590d6" name="files[]" multiple disabled />
#      <output id="result-ab4bce73-eb93-4f75-a249-24929f3590d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data_test_clean.csv to data_test_clean.csv

# %%
import nltk
nltk.download('twitter_samples')
from nltk.corpus import twitter_samples
print (twitter_samples.fileids())

pos_tweets = twitter_samples.strings('positive_tweets.json')
print (len(pos_tweets)) # Output: 5000
neg_tweets = twitter_samples.strings('negative_tweets.json')
print (len(neg_tweets)) # Output: 5000
all_tweets = twitter_samples.strings('tweets.20150430-223406.json')
print (len(all_tweets)) # Output: 20000
for tweet in pos_tweets[:5]:
 print (tweet)
# Out:
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# ['negative_tweets.json', 'positive_tweets.json', 'tweets.20150430-223406.json']
# 5000
# 5000
# 20000
# #FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)
# @Lamb2ja Hey James! How odd :/ Please call our Contact Centre on 02392441234 and we will be able to assist you :) Many thanks!
# @DespiteOfficial we had a listen last night :) As You Bleed is an amazing track. When are you in Scotland?!
# @97sides CONGRATS :)
# yeaaaah yippppy!!!  my accnt verified rqst has succeed got a blue tick mark on my fb profile :) in 15 days

# %%
import nltk
import textblob
import string
from nltk.tokenize import word_tokenize
from string import punctuation 
from nltk.corpus import stopwords
from textblob import  TextBlob
import re
import pandas as pd

# %%
from nltk.tokenize import TweetTokenizer
tweet_tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
for tweet in pos_tweets[:5]:
   print (tweet_tokenizer.tokenize(tweet))
# Out:
# ['#followfriday', 'for', 'being', 'top', 'engaged', 'members', 'in', 'my', 'community', 'this', 'week', ':)']
# ['hey', 'james', '!', 'how', 'odd', ':/', 'please', 'call', 'our', 'contact', 'centre', 'on', '02392441234', 'and', 'we', 'will', 'be', 'able', 'to', 'assist', 'you', ':)', 'many', 'thanks', '!']
# ['we', 'had', 'a', 'listen', 'last', 'night', ':)', 'as', 'you', 'bleed', 'is', 'an', 'amazing', 'track', '.', 'when', 'are', 'you', 'in', 'scotland', '?', '!']
# ['congrats', ':)']
# ['yeaaah', 'yipppy', '!', '!', '!', 'my', 'accnt', 'verified', 'rqst', 'has', 'succeed', 'got', 'a', 'blue', 'tick', 'mark', 'on', 'my', 'fb', 'profile', ':)', 'in', '15', 'days']

# %%
df=pd.read_csv('data_test_clean.csv')

# %%
df.head()
# Out:
#                  id  ... identity_hate
# 0  7ca72b5b9c688e9e  ...             0
# 1  c03f72fd8f8bf54f  ...             0
# 2  9e5b8e8fc1ff2e84  ...             0
# 3  5332799e706665a6  ...             0
# 4  dfa7d8f0b4366680  ...             0
#
# [5 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47872 entries, 0 to 47871
# Data columns (total 8 columns):
# id               47872 non-null object
# clean_comment    47872 non-null object
# toxic            47872 non-null int64
# severe_toxic     47872 non-null int64
# obscene          47872 non-null int64
# threat           47872 non-null int64
# insult           47872 non-null int64
# identity_hate    47872 non-null int64
# dtypes: int64(6), object(2)
# memory usage: 2.9+ MB

# %%
def clean_tweet(clean_comment):
    return ' '.join(re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)', ' ',clean_comment).split())

# %%
from bs4 import BeautifulSoup
example1 = BeautifulSoup(df.clean_comment[47871], 'lxml')
#print example1.get_text()

# %%
from nltk.tokenize import WordPunctTokenizer
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
combined_pat = r'|'.join((pat1, pat2))
def tweet_cleaner(clean_comment):
    soup = BeautifulSoup(
        clean_comment, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters_only.lower()
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(lower_case)
    return (" ".join(words)).strip()
testing = df.clean_comment[0:47871]
test_result = []
for t in testing:
    test_result.append(tweet_cleaner(t))
test_result
# Out:
# ['b geez are you forgetful we have already discussed why marx was not an anarchist ie he wanted to use a state to mold his socialist man ergo he is a statist the opposite of an anarchist i know a guy who says that when he gets old and his teeth fall out he will quit eating meat would you call him a vegetarian',
#  'b carioca rfa thanks for your support on my request for adminship the final outcome was so i am now an administrator if you have any comments or concerns on my actions as an administrator please let me know thank you',
#  'b birthday no worries it is what i do enjoy ur daytalke',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47872 entries, 0 to 47871
# Data columns (total 8 columns):
# id               47872 non-null object
# clean_comment    47872 non-null object
# toxic            47872 non-null int64
# severe_toxic     47872 non-null int64
# obscene          47872 non-null int64
# threat           47872 non-null int64
# insult           47872 non-null int64
# identity_hate    47872 non-null int64
# dtypes: int64(6), object(2)
# memory usage: 2.9+ MB

# %%
from nltk.tokenize import WordPunctTokenizer
tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
combined_pat = r'|'.join((pat1, pat2))
def tweet_cleaner(clean_comment):
    soup = BeautifulSoup(clean_comment, 'lxml')
    souped = soup.get_text()
    stripped = re.sub(combined_pat, '', souped)
    try:
        clean = stripped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        clean = stripped
    letters_only = re.sub("[^a-zA-Z]", " ", clean)
    lower_case = letters_only.lower()
    # During the letters_only process two lines above, it has created unnecessay white spaces,
    # I will tokenize and join together to remove unneccessary white spaces
    words = tok.tokenize(lower_case)
    return (" ".join(words)).strip()
testing = df.clean_comment[0:47871]
test_result = []
for t in testing:
    test_result.append(tweet_cleaner(t))
test_result
# Out:
# ['b geez are you forgetful we have already discussed why marx was not an anarchist ie he wanted to use a state to mold his socialist man ergo he is a statist the opposite of an anarchist i know a guy who says that when he gets old and his teeth fall out he will quit eating meat would you call him a vegetarian',
#  'b carioca rfa thanks for your support on my request for adminship the final outcome was so i am now an administrator if you have any comments or concerns on my actions as an administrator please let me know thank you',
#  'b birthday no worries it is what i do enjoy ur daytalke',
# ...

# %%
testing = df.clean_comment[0:47871]

# %%
testing.replace(u"\ufffd", "?")
# Out:
# 0        b'geez are you forgetful we have already discu...
# 1        b'carioca rfa thanks for your support on my re...
# 2        b' birthday no worries it is what i do enjoy u...
# 3        b'pseudoscience category i am assuming that th...
# 4        b'and if such phrase exists it would be provid...
#                                ...
# 47866                              b' i removed them pika'
# 47867    b' his documented emotional involvements with ...
# 47868    b'rename i do not know if it has been done or ...
# 47869                         b'just random nazi soldiers'
# 47870                      b'add comments below this line'
# Name: clean_comment, Length: 47871, dtype: object

# %%
nums = [0,47871]
print("Cleaning and parsing the tweets...\n")
clean_tweet_texts = []
for i in range(nums[0],nums[1]):
    if( (i+1)%10000 == 0 ):
        print("Tweets %d of %d has been processed" % ( i+1, nums[1]))                                                                    
    clean_tweet_texts.append(tweet_cleaner(df['clean_comment'][i]))
# Out:
# Cleaning and parsing the tweets...
#
# Tweets 10000 of 47871 has been processed
# Tweets 20000 of 47871 has been processed
# Tweets 30000 of 47871 has been processed
# Tweets 40000 of 47871 has been processed

# %%
df =df.dropna(axis = 0, how ='any')

# %%
df.to_csv('datatestclean.csv',encoding='utf-8')
csv = 'datatestclean.csv'

# %%
my_df = pd.read_csv(csv,index_col=0)
my_df.head()
# Out:
#                  id  ... identity_hate
# 0  7ca72b5b9c688e9e  ...             0
# 1  c03f72fd8f8bf54f  ...             0
# 2  9e5b8e8fc1ff2e84  ...             0
# 3  5332799e706665a6  ...             0
# 4  dfa7d8f0b4366680  ...             0
#
# [5 rows x 8 columns]

# %%
my_df.dropna()
# Out:
#                      id  ... identity_hate
# 0      7ca72b5b9c688e9e  ...             0
# 1      c03f72fd8f8bf54f  ...             0
# 2      9e5b8e8fc1ff2e84  ...             0
# 3      5332799e706665a6  ...             0
# 4      dfa7d8f0b4366680  ...             0
# ...                 ...  ...           ...
# 47867  a5e8811002c2e965  ...             0
# 47868  703c79bd1ef1f61d  ...             0
# 47869  cd618fa54e2da21d  ...             0
# 47870  d99ec9d910520101  ...             0
# 47871  23f6d004bfd9ed1d  ...             0
#
# [47872 rows x 8 columns]

# %%
from google.colab import files
files.download("datatestclean.csv")
